# %%
import joblib
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.cm as cm

from sklearn.cluster import KMeans
from sklearn.metrics import davies_bouldin_score
from sklearn.metrics import silhouette_score, silhouette_samples, calinski_harabasz_score
import matplotlib.pyplot as plt

from mealpy import FloatVar, ABC
from scipy.spatial.distance import cdist

# %%
pca_data = pd.read_csv("./results/pca_data.csv")
pca_data.head()
# Out:
#         fecha referencia       PC1       PC2       PC3       PC4       PC5  \
# 0  04/06/2001         P1 -2.173814  0.560687 -0.244653 -0.000022 -0.198642
# 1  04/06/2001         P2 -2.135326  0.504553 -0.095536 -0.305302 -0.183530
# 2  04/06/2001         P3 -2.165984  0.458176 -0.002323 -0.326949 -0.166642
# 3  04/06/2001         P4 -2.211613  0.503966 -0.129927 -0.042172 -0.189566
# 4  04/07/2001         P1 -2.324292  0.460397 -0.136303  0.202740 -0.166470
#
#         PC6       PC7       PC8       PC9      PC10
# 0 -0.297102 -0.449977 -0.315806 -0.283185 -0.048349
# 1  0.056558 -0.207734 -0.030956  0.008387 -0.057170
# 2  0.099856 -0.208867  0.031741  0.089761  0.017689
# 3 -0.223255 -0.443616 -0.230362 -0.179810  0.050264
# 4 -0.296635 -0.488494 -0.353747 -0.337112  0.184335

# %% [markdown]
# ## Entrenamiento para clasificación con K-Means
#
# Para realizar un entrenamiento no supervisado con una base de datos de parámetros químicos, la mejor opción es utilizar un Mapa Auto-Organizado (SOM) o un Autoencoder. Sin embargo, dado que ya se tiene los componentes principales (PCA), la técnica más robusta y estándar para encontrar grupos (clusters) es el K-Means Clustering potenciado por una Red Neuronal para validación.
#
# ### Preparación de los datos (Inputs del PCA)
#
# Usaremos los componentes que explican la mayor parte de la varianza (según tu tabla, los primeros 5 o 6 son los más informativos).

# %%
# Usamos los resultados del PCA (asumiendo que df_pca tiene tus componentes)
# Seleccionamos, por ejemplo, los primeros 5 componentes principales
X_unsupervised = pca_data.iloc[:, 2:6] 

# Determinamos el número óptimo de clusters (Método del Codo)
wcss = []
for i in range(1, 11):
    kmeans = KMeans(n_clusters=i, init='k-means++', random_state=42)
    kmeans.fit(X_unsupervised)
    wcss.append(kmeans.inertia_)

plt.plot(range(1, 11), wcss, marker='o')
plt.title('Método del Codo para detectar Clusters')
plt.xlabel('Número de clusters')
plt.ylabel('WCSS (Inercia)')
plt.show()

# %%
# metodo de coeficiente de silueta
n_range_clusters = 9
silhouette_data = np.zeros([n_range_clusters,2])

for n_clusters in range(2, n_range_clusters+2):
    # Crear el subplot
    fig, ax1 = plt.subplots(1, 1)
    ax1.set_xlim([-0.1, 1])
    
    # Entrenar el modelo
    clusterer = KMeans(n_clusters=n_clusters, random_state=10)
    cluster_labels = clusterer.fit_predict(X_unsupervised)

    # Calcular el promedio de silueta (la línea punteada)
    silhouette_avg = silhouette_score(X_unsupervised, cluster_labels)
    print(f"Para n_clusters = {n_clusters}, el promedio es: {silhouette_avg:.3f}")

    # Calcular el coeficiente de cada muestra
    sample_silhouette_values = silhouette_samples(X_unsupervised, cluster_labels)

    y_lower = 10
    for i in range(n_clusters):
        ith_cluster_silhouette_values = sample_silhouette_values[cluster_labels == i]
        ith_cluster_silhouette_values.sort()

        size_cluster_i = ith_cluster_silhouette_values.shape[0]
        y_upper = y_lower + size_cluster_i

        color = cm.nipy_spectral(float(i) / n_clusters)
        ax1.fill_betweenx(np.arange(y_lower, y_upper), 0, ith_cluster_silhouette_values,
                          facecolor=color, edgecolor=color, alpha=0.7)

        y_lower = y_upper + 10 

    ax1.axvline(x=silhouette_avg, color="red", linestyle="--")
    ax1.set_title(f"Análisis de Silueta para k = {n_clusters}")
    plt.show()

    silhouette_data[n_clusters-2, 0] = n_clusters
    silhouette_data[n_clusters-2, 1] = silhouette_avg

plt.plot(silhouette_data[:,0], silhouette_data[:,1])
# Out:
# Para n_clusters = 2, el promedio es: 0.410
# Para n_clusters = 3, el promedio es: 0.388
# Para n_clusters = 4, el promedio es: 0.397
# Para n_clusters = 5, el promedio es: 0.396
# Para n_clusters = 6, el promedio es: 0.372
# Para n_clusters = 7, el promedio es: 0.387
# Para n_clusters = 8, el promedio es: 0.324
# Para n_clusters = 9, el promedio es: 0.319
# Para n_clusters = 10, el promedio es: 0.313

# %% [markdown]
# ### Entrenamiento del Modelo de Clasificación
#
# Una vez identificado el número de grupos (supongamos que el "codo" está en 3 o 4 clusters), ejecutamos el entrenamiento final.

# %%
# Entrenamos con el número de clusters elegido (ejemplo: 4)
n_clusters_optimo = 3
model = KMeans(n_clusters=n_clusters_optimo, init='k-means++', random_state=42)
clusters = model.fit_predict(X_unsupervised)

# Añadimos la clasificación a nuestro DataFrame original
# data_fixed['cluster_id'] = clusters

# %% [markdown]
# ### Gráfico de Dispersión 2D (Visualización Estándar)
#
# Primero, asegúrate de tener en un solo lugar los componentes y las etiquetas de los clusters que generó el modelo.

# %%
# Creamos un DataFrame auxiliar para graficar
cp_grafico = ['PC1', 'PC2']
df_grafico = pca_data[cp_grafico].copy()
df_grafico['cluster_knn'] = clusters # Las etiquetas que generó tu modelo K-Means

# Agregamos una columna de texto para que la leyenda sea más clara
# df_grafico['Cluster_Name'] = df_grafico['Cluster'].apply(lambda x: f'Grupo {x}')

# %% [markdown]
# Este gráfico te permitirá ver cómo el algoritmo separó las muestras de agua. Si los grupos están bien definidos, verás "nubes" de puntos de distintos colores.

# %%
fig_1, axes_1 = plt.subplots(1, 2, figsize=(12, 5))
sns.scatterplot(
    data=df_grafico, 
    x=cp_grafico[0], 
    y=cp_grafico[1], 
    hue='cluster_knn', 
    palette='viridis', 
    s=70, 
    alpha=1,
    edgecolor='w',
    ax=axes_1[0]
)

sns.histplot(data=df_grafico, x='cluster_knn', ax=axes_1[1])

# Personalización de títulos (basado en tu interpretación de loadings)
axes_1[0].set_title('Clusters K-Means')
axes_1[0].set_xlabel(f'{cp_grafico[0]}')
axes_1[0].set_ylabel(f'{cp_grafico[1]}')

axes_1[1].set_title('Distribución en clusters')
axes_1[1].set_xlabel(f'Clusters')
axes_1[1].set_ylabel(f'Frecuencia')

# plt.legend(title='Clasificación', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.grid(True, linestyle='--', alpha=0.5)
plt.show()

# %% [markdown]
# ## Entrenamiento con Autoencoder

# %%
# pendiente

# %% [markdown]
# ### Híbrido ABC + K-Means (Refinamiento)
# En este modelo, el ABC se encarga de la exploración global y el K-Means de la explotación local.
#
# 1. Fase Global (ABC): Las abejas exploran el espacio de datos para encontrar regiones prometedoras donde podrían estar los clusters.
#
# 2. Fase Local (K-Means): Una vez que el ABC encuentra una solución cercana a la óptima, se utiliza el operador de K-Means para "pulir" esos centroides y ajustarlos rápidamente a los datos circundantes.
#
# Resultado: Es mucho más rápido que el ABC puro y más preciso que el K-Means solo.
#
#
# ### El Flujo de Trabajo
#
# La idea central es usar el ABC para inicializar de forma inteligente los centroides y luego dejar que K-Means termine el trabajo sucio de convergencia.
#
# 1. Inicialización (Abejas Exploradoras)En lugar de elegir puntos al azar, generas una población de "abejas". Cada abeja lleva consigo un vector que representa los centros de los $k$ clusters.
#
# - Población: $N$ soluciones potenciales.
# - Posición: Coordenadas de los centros de los grupos en el espacio de datos.2. Ciclo de
#
# 2. Optimización Global (Fase ABC)Durante un número determinado de iteraciones, las abejas realizan tres tareas:
# - Abejas Empleadas: Buscan nuevas soluciones cerca de las actuales (modifican un poco los centros) para ver si el error (SSE) disminuye.
# - Abejas Observadoras: Eligen las mejores soluciones encontradas basándose en una probabilidad de "fitness". Entre mejor sea el clustering, más abejas irán a esa zona.
# - Abejas Exploradoras: Si una solución no mejora después de varios intentos, la abeja la abandona y vuela a una zona totalmente nueva del dataset para evitar el estancamiento.
#
# 3. El "Salto" a K-Means (Refinamiento Local)Una vez que el algoritmo ABC ha convergido en una región prometedora (es decir, ya tenemos centros muy cercanos a los reales), tomamos la mejor abeja y usamos sus posiciones como el init de un algoritmo K-Means tradicional.
#
# 4. FinalizaciónK-Means realiza sus iteraciones finales (que suelen ser muy pocas en este punto) para asegurar que cada punto esté asignado al centroide más cercano de forma exacta.
#
# ```bash
# # 1. Fase Global (Exploración con ABC)
# for iteracion in rango(max_iter_abc):
#     for abeja in poblacion:
#         nueva_posicion = mover_abeja(abeja)
#         evaluar_fitness(nueva_posicion) # Usando Suma de Errores Cuadráticos
#     manejar_abejas_exploradoras() # Evita mínimos locales
#
# # 2. Selección del Ganador
# mejor_solucion = obtener_mejor_abeja(poblacion)
#
# # 3. Fase Local (Refinamiento con K-Means)
# # Usamos la mejor posición del ABC como semilla
# kmeans_final = KMeans(n_clusters=k, init=mejor_solucion.centros)
# kmeans_final.fit(datos)
# ```

# %%
data = pca_data.drop(columns=['fecha', 'referencia']).copy()

n_clusters = 3
n_features = data.shape[1]

# 1.1 Función de Aptitud (Fitness)
def fitness_aptitude(solution):
    centroids = solution.reshape((n_clusters, n_features))
    distances = cdist(data, centroids, 'euclidean')
    labels = np.argmin(distances, axis=1)
    
    # Penalización si se pierde un cluster
    if len(np.unique(labels)) < n_clusters:
        return 1e18
    
    # Cálculo de SSE (Suma de errores cuadráticos)
    sse = 0
    for i in range(n_clusters):
        cluster_points = data[labels == i]
        sse += np.sum((cluster_points - centroids[i])**2)
    return sse

# 1.2. Índice de Davies-Bouldin (DBI)
def fitness_db_index(solution):
    centroids = solution.reshape((n_clusters, n_features))
    distances = cdist(data, centroids, 'euclidean')
    labels = np.argmin(distances, axis=1)
    
    if len(np.unique(labels)) < n_clusters:
        return 1e18
    
    # El objetivo es MINIMIZAR este índice
    return davies_bouldin_score(data, labels)

# 1.3 Índice de Calinski-Harabasz (Varianza entre/dentro)
def fitness_calinski(solution):
    centroids = solution.reshape((n_clusters, n_features))
    distances = cdist(data, centroids, 'euclidean')
    labels = np.argmin(distances, axis=1)
    
    if len(np.unique(labels)) < n_clusters:
        return 1e18
    
    score = calinski_harabasz_score(data, labels)
    # Como buscamos MINIMIZAR en tu config, retornamos el negativo
    return -score

# 1.4 Función de Fitness Combinada (Híbrida)
def fitness_hybrid(solution):
    centroids = solution.reshape((n_clusters, n_features))
    distances = cdist(data, centroids, 'euclidean')
    labels = np.argmin(distances, axis=1)
    
    if len(np.unique(labels)) < n_clusters:
        return 1e18
    
    # 1. Calcular SSE
    sse = 0
    for i in range(n_clusters):
        cluster_points = data[labels == i]
        sse += np.sum((cluster_points - centroids[i])**2)
    
    # 2. Calcular separación entre centroides (queremos que sea grande)
    # Calculamos la distancia promedio entre todos los pares de centros
    sep_distances = cdist(centroids, centroids, 'euclidean')
    # Sumamos solo la parte triangular superior para no repetir distancias ni usar la diagonal (0)
    separation = np.sum(np.triu(sep_distances, k=1))
    
    # Retornamos SSE penalizado por poca separación
    # (A menor separación, mayor el valor del fitness)
    return sse / (separation + 1e-6)

# 3. Configuración del Problema
low_bounds = np.min(data, axis=0).tolist() * n_clusters
up_bounds = np.max(data, axis=0).tolist() * n_clusters

problem_dict = {
    "obj_func": fitness_calinski,
    "bounds": FloatVar(lb=low_bounds, ub=up_bounds),
    "minmax": "min",
}

# 4. Ejecución de ABC
model = ABC.OriginalABC(epoch=100, pop_size=50)

# CORRECCIÓN AQUÍ: Obtenemos el objeto 'g_best' (Global Best Agent)
g_best = model.solve(problem_dict)

# Extraemos la posición y el fitness del objeto Agent
best_pos = g_best.solution 
best_fit = g_best.target.fitness

print(f"Mejor Fitness (SSE) encontrado por ABC: {best_fit}")
# Out:
# 2026/03/07 11:32:51 AM, INFO, mealpy.swarm_based.ABC.OriginalABC: OriginalABC(epoch=100, pop_size=50, n_limits=25)
# 2026/03/07 11:32:51 AM, INFO, mealpy.swarm_based.ABC.OriginalABC: >>>Problem: P, Epoch: 1, Current best: -90.14496239870992, Global best: -90.14496239870992, Runtime: 0.09844 seconds
# 2026/03/07 11:32:51 AM, INFO, mealpy.swarm_based.ABC.OriginalABC: >>>Problem: P, Epoch: 2, Current best: -90.14496239870992, Global best: -90.14496239870992, Runtime: 0.07619 seconds
# 2026/03/07 11:32:51 AM, INFO, mealpy.swarm_based.ABC.OriginalABC: >>>Problem: P, Epoch: 3, Current best: -97.97849932965067, Global best: -97.97849932965067, Runtime: 0.07591 seconds
# 2026/03/07 11:32:51 AM, INFO, mealpy.swarm_based.ABC.OriginalABC: >>>Problem: P, Epoch: 4, Current best: -97.97849932965067, Global best: -97.97849932965067, Runtime: 0.08024 seconds
# 2026/03/07 11:32:51 AM, INFO, mealpy.swarm_based.ABC.OriginalABC: >>>Problem: P, Epoch: 5, Current best: -97.97849932965067, Global best: -97.97849932965067, Runtime: 0.07517 seconds
# 2026/03/07 11:32:52 AM, INFO, mealpy.swarm_based.ABC.OriginalABC: >>>Problem: P, Epoch: 6, Current best: -97.97849932965067, Global best: -97.97849932965067, Runtime: 0.07399 seconds
# 2026/03/07 11:32:52 AM, INFO, mealpy.swarm_based.ABC.OriginalABC: >>>Problem: P, Epoch: 7, Current best: -97.97849932965067, Global best: -97.97849932965067, Runtime: 0.07460 seconds
# 2026/03/07 11:32:52 AM, INFO, mealpy.swarm_based.ABC.OriginalABC: >>>Problem: P, Epoch: 8, Current best: -97.97849932965067, Global best: -97.97849932965067, Runtime: 0.07753 seconds
# 2026/03/07 11:32:52 AM, INFO, mealpy.swarm_based.ABC.OriginalABC: >>>Problem: P, Epoch: 9, Current best: -90.14496239870992, Global best: -97.97849932965067, Runtime: 0.07415 seconds
# 2026/03/07 11:32:52 AM, INFO, mealpy.swarm_based.ABC.OriginalABC: >>>Problem: P, Epoch: 10, Current best: -86.50549731027776, Global best: -97.97849932965067, Runtime: 0.07657 seconds
# 2026/03/07 11:32:52 AM, INFO, mealpy.swarm_based.ABC.OriginalABC: >>>Problem: P, Epoch: 11, Current best: -87.7284504721443, Global best: -97.97849932965067, Runtime: 0.07772 seconds
# 2026/03/07 11:32:52 AM, INFO, mealpy.swarm_based.ABC.OriginalABC: >>>Problem: P, Epoch: 12, Current best: -98.60205476172159, Global best: -98.60205476172159, Runtime: 0.07593 seconds
# 2026/03/07 11:32:52 AM, INFO, mealpy.swarm_based.ABC.OriginalABC: >>>Problem: P, Epoch: 13, Current best: -98.60205476172159, Global best: -98.60205476172159, Runtime: 0.07797 seconds
# 2026/03/07 11:32:52 AM, INFO, mealpy.swarm_based.ABC.OriginalABC: >>>Problem: P, Epoch: 14, Current best: -98.60205476172159, Global best: -98.60205476172159, Runtime: 0.07456 seconds
# 2026/03/07 11:32:52 AM, INFO, mealpy.swarm_based.ABC.OriginalABC: >>>Problem: P, Epoch: 15, Current best: -98.60205476172159, Global best: -98.60205476172159, Runtime: 0.07808 seconds
# 2026/03/07 11:32:52 AM, INFO, mealpy.swarm_based.ABC.OriginalABC: >>>Problem: P, Epoch: 16, Current best: -98.60205476172159, Global best: -98.60205476172159, Runtime: 0.07810 seconds
# 2026/03/07 11:32:52 AM, INFO, mealpy.swarm_based.ABC.OriginalABC: >>>Problem: P, Epoch: 17, Current best: -98.60205476172159, Global best: -98.60205476172159, Runtime: 0.07323 seconds
# 2026/03/07 11:32:52 AM, INFO, mealpy.swarm_based.ABC.OriginalABC: >>>Problem: P, Epoch: 18, Current best: -98.60205476172159, Global best: -98.60205476172159, Runtime: 0.07951 seconds
# 2026/03/07 11:32:53 AM, INFO, mealpy.swarm_based.ABC.OriginalABC: >>>Problem: P, Epoch: 19, Current best: -99.67441303235785, Global best: -99.67441303235785, Runtime: 0.07844 seconds
# 2026/03/07 11:32:53 AM, INFO, mealpy.swarm_based.ABC.OriginalABC: >>>Problem: P, Epoch: 20, Current best: -99.67441303235785, Global best: -99.67441303235785, Runtime: 0.08137 seconds
# 2026/03/07 11:32:53 AM, INFO, mealpy.swarm_based.ABC.OriginalABC: >>>Problem: P, Epoch: 21, Current best: -99.67441303235785, Global best: -99.67441303235785, Runtime: 0.07967 seconds
# 2026/03/07 11:32:53 AM, INFO, mealpy.swarm_based.ABC.OriginalABC: >>>Problem: P, Epoch: 22, Current best: -99.67441303235785, Global best: -99.67441303235785, Runtime: 0.08170 seconds
# 2026/03/07 11:32:53 AM, INFO, mealpy.swarm_based.ABC.OriginalABC: >>>Problem: P, Epoch: 23, Current best: -99.67441303235785, Global best: -99.67441303235785, Runtime: 0.07851 seconds
# 2026/03/07 11:32:53 AM, INFO, mealpy.swarm_based.ABC.OriginalABC: >>>Problem: P, Epoch: 24, Current best: -99.67441303235785, Global best: -99.67441303235785, Runtime: 0.07699 seconds
# 2026/03/07 11:32:53 AM, INFO, mealpy.swarm_based.ABC.OriginalABC: >>>Problem: P, Epoch: 25, Current best: -99.67441303235785, Global best: -99.67441303235785, Runtime: 0.08255 seconds
# 2026/03/07 11:32:53 AM, INFO, mealpy.swarm_based.ABC.OriginalABC: >>>Problem: P, Epoch: 26, Current best: -98.90971030244398, Global best: -99.67441303235785, Runtime: 0.08390 seconds
# 2026/03/07 11:32:53 AM, INFO, mealpy.swarm_based.ABC.OriginalABC: >>>Problem: P, Epoch: 27, Current best: -98.90971030244398, Global best: -99.67441303235785, Runtime: 0.08423 seconds
# 2026/03/07 11:32:53 AM, INFO, mealpy.swarm_based.ABC.OriginalABC: >>>Problem: P, Epoch: 28, Current best: -98.90971030244398, Global best: -99.67441303235785, Runtime: 0.08254 seconds
# 2026/03/07 11:32:53 AM, INFO, mealpy.swarm_based.ABC.OriginalABC: >>>Problem: P, Epoch: 29, Current best: -102.50204335418, Global best: -102.50204335418, Runtime: 0.07852 seconds
# 2026/03/07 11:32:53 AM, INFO, mealpy.swarm_based.ABC.OriginalABC: >>>Problem: P, Epoch: 30, Current best: -102.50204335418, Global best: -102.50204335418, Runtime: 0.07627 seconds
# 2026/03/07 11:32:54 AM, INFO, mealpy.swarm_based.ABC.OriginalABC: >>>Problem: P, Epoch: 31, Current best: -102.50204335418, Global best: -102.50204335418, Runtime: 0.08186 seconds
# 2026/03/07 11:32:54 AM, INFO, mealpy.swarm_based.ABC.OriginalABC: >>>Problem: P, Epoch: 32, Current best: -102.50204335418, Global best: -102.50204335418, Runtime: 0.07458 seconds
# 2026/03/07 11:32:54 AM, INFO, mealpy.swarm_based.ABC.OriginalABC: >>>Problem: P, Epoch: 33, Current best: -102.50204335418, Global best: -102.50204335418, Runtime: 0.07428 seconds
# 2026/03/07 11:32:54 AM, INFO, mealpy.swarm_based.ABC.OriginalABC: >>>Problem: P, Epoch: 34, Current best: -102.50204335418, Global best: -102.50204335418, Runtime: 0.07907 seconds
# 2026/03/07 11:32:54 AM, INFO, mealpy.swarm_based.ABC.OriginalABC: >>>Problem: P, Epoch: 35, Current best: -102.50204335418, Global best: -102.50204335418, Runtime: 0.07385 seconds
# 2026/03/07 11:32:54 AM, INFO, mealpy.swarm_based.ABC.OriginalABC: >>>Problem: P, Epoch: 36, Current best: -102.50204335418, Global best: -102.50204335418, Runtime: 0.07736 seconds
# 2026/03/07 11:32:54 AM, INFO, mealpy.swarm_based.ABC.OriginalABC: >>>Problem: P, Epoch: 37, Current best: -95.75765038875232, Global best: -102.50204335418, Runtime: 0.07824 seconds
# 2026/03/07 11:32:54 AM, INFO, mealpy.swarm_based.ABC.OriginalABC: >>>Problem: P, Epoch: 38, Current best: -94.29546932130646, Global best: -102.50204335418, Runtime: 0.08011 seconds
# 2026/03/07 11:32:54 AM, INFO, mealpy.swarm_based.ABC.OriginalABC: >>>Problem: P, Epoch: 39, Current best: -94.29546932130646, Global best: -102.50204335418, Runtime: 0.07730 seconds
# 2026/03/07 11:32:54 AM, INFO, mealpy.swarm_based.ABC.OriginalABC: >>>Problem: P, Epoch: 40, Current best: -94.29546932130646, Global best: -102.50204335418, Runtime: 0.07744 seconds
# 2026/03/07 11:32:54 AM, INFO, mealpy.swarm_based.ABC.OriginalABC: >>>Problem: P, Epoch: 41, Current best: -94.29546932130646, Global best: -102.50204335418, Runtime: 0.07150 seconds
# 2026/03/07 11:32:54 AM, INFO, mealpy.swarm_based.ABC.OriginalABC: >>>Problem: P, Epoch: 42, Current best: -94.29546932130646, Global best: -102.50204335418, Runtime: 0.07583 seconds
# 2026/03/07 11:32:54 AM, INFO, mealpy.swarm_based.ABC.OriginalABC: >>>Problem: P, Epoch: 43, Current best: -94.29546932130646, Global best: -102.50204335418, Runtime: 0.07756 seconds
# 2026/03/07 11:32:55 AM, INFO, mealpy.swarm_based.ABC.OriginalABC: >>>Problem: P, Epoch: 44, Current best: -99.8881571202688, Global best: -102.50204335418, Runtime: 0.07578 seconds
# 2026/03/07 11:32:55 AM, INFO, mealpy.swarm_based.ABC.OriginalABC: >>>Problem: P, Epoch: 45, Current best: -99.8881571202688, Global best: -102.50204335418, Runtime: 0.08384 seconds
# 2026/03/07 11:32:55 AM, INFO, mealpy.swarm_based.ABC.OriginalABC: >>>Problem: P, Epoch: 46, Current best: -99.8881571202688, Global best: -102.50204335418, Runtime: 0.08110 seconds
# 2026/03/07 11:32:55 AM, INFO, mealpy.swarm_based.ABC.OriginalABC: >>>Problem: P, Epoch: 47, Current best: -99.8881571202688, Global best: -102.50204335418, Runtime: 0.07814 seconds
# 2026/03/07 11:32:55 AM, INFO, mealpy.swarm_based.ABC.OriginalABC: >>>Problem: P, Epoch: 48, Current best: -99.8881571202688, Global best: -102.50204335418, Runtime: 0.07938 seconds
# 2026/03/07 11:32:55 AM, INFO, mealpy.swarm_based.ABC.OriginalABC: >>>Problem: P, Epoch: 49, Current best: -99.8881571202688, Global best: -102.50204335418, Runtime: 0.07921 seconds
# 2026/03/07 11:32:55 AM, INFO, mealpy.swarm_based.ABC.OriginalABC: >>>Problem: P, Epoch: 50, Current best: -99.95789071779893, Global best: -102.50204335418, Runtime: 0.07706 seconds
# 2026/03/07 11:32:55 AM, INFO, mealpy.swarm_based.ABC.OriginalABC: >>>Problem: P, Epoch: 51, Current best: -99.95789071779893, Global best: -102.50204335418, Runtime: 0.08078 seconds
# 2026/03/07 11:32:55 AM, INFO, mealpy.swarm_based.ABC.OriginalABC: >>>Problem: P, Epoch: 52, Current best: -99.95789071779893, Global best: -102.50204335418, Runtime: 0.07827 seconds
# 2026/03/07 11:32:55 AM, INFO, mealpy.swarm_based.ABC.OriginalABC: >>>Problem: P, Epoch: 53, Current best: -101.37250483199234, Global best: -102.50204335418, Runtime: 0.07849 seconds
# 2026/03/07 11:32:55 AM, INFO, mealpy.swarm_based.ABC.OriginalABC: >>>Problem: P, Epoch: 54, Current best: -101.37250483199234, Global best: -102.50204335418, Runtime: 0.07376 seconds
# 2026/03/07 11:32:55 AM, INFO, mealpy.swarm_based.ABC.OriginalABC: >>>Problem: P, Epoch: 55, Current best: -101.37250483199234, Global best: -102.50204335418, Runtime: 0.08017 seconds
# 2026/03/07 11:32:55 AM, INFO, mealpy.swarm_based.ABC.OriginalABC: >>>Problem: P, Epoch: 56, Current best: -101.37250483199234, Global best: -102.50204335418, Runtime: 0.07754 seconds
# 2026/03/07 11:32:56 AM, INFO, mealpy.swarm_based.ABC.OriginalABC: >>>Problem: P, Epoch: 57, Current best: -101.37250483199234, Global best: -102.50204335418, Runtime: 0.07585 seconds
# 2026/03/07 11:32:56 AM, INFO, mealpy.swarm_based.ABC.OriginalABC: >>>Problem: P, Epoch: 58, Current best: -101.37250483199234, Global best: -102.50204335418, Runtime: 0.08779 seconds
# 2026/03/07 11:32:56 AM, INFO, mealpy.swarm_based.ABC.OriginalABC: >>>Problem: P, Epoch: 59, Current best: -101.37250483199234, Global best: -102.50204335418, Runtime: 0.07912 seconds
# 2026/03/07 11:32:56 AM, INFO, mealpy.swarm_based.ABC.OriginalABC: >>>Problem: P, Epoch: 60, Current best: -101.37250483199234, Global best: -102.50204335418, Runtime: 0.07422 seconds
# 2026/03/07 11:32:56 AM, INFO, mealpy.swarm_based.ABC.OriginalABC: >>>Problem: P, Epoch: 61, Current best: -101.37250483199234, Global best: -102.50204335418, Runtime: 0.07577 seconds
# 2026/03/07 11:32:56 AM, INFO, mealpy.swarm_based.ABC.OriginalABC: >>>Problem: P, Epoch: 62, Current best: -100.14809524157067, Global best: -102.50204335418, Runtime: 0.07877 seconds
# 2026/03/07 11:32:56 AM, INFO, mealpy.swarm_based.ABC.OriginalABC: >>>Problem: P, Epoch: 63, Current best: -99.19763748345999, Global best: -102.50204335418, Runtime: 0.08023 seconds
# 2026/03/07 11:32:56 AM, INFO, mealpy.swarm_based.ABC.OriginalABC: >>>Problem: P, Epoch: 64, Current best: -99.19763748345999, Global best: -102.50204335418, Runtime: 0.07683 seconds
# 2026/03/07 11:32:56 AM, INFO, mealpy.swarm_based.ABC.OriginalABC: >>>Problem: P, Epoch: 65, Current best: -99.19763748345999, Global best: -102.50204335418, Runtime: 0.07849 seconds
# 2026/03/07 11:32:56 AM, INFO, mealpy.swarm_based.ABC.OriginalABC: >>>Problem: P, Epoch: 66, Current best: -96.27722976345365, Global best: -102.50204335418, Runtime: 0.07752 seconds
# 2026/03/07 11:32:56 AM, INFO, mealpy.swarm_based.ABC.OriginalABC: >>>Problem: P, Epoch: 67, Current best: -96.27722976345365, Global best: -102.50204335418, Runtime: 0.07735 seconds
# 2026/03/07 11:32:56 AM, INFO, mealpy.swarm_based.ABC.OriginalABC: >>>Problem: P, Epoch: 68, Current best: -95.20182134678582, Global best: -102.50204335418, Runtime: 0.07764 seconds
# 2026/03/07 11:32:56 AM, INFO, mealpy.swarm_based.ABC.OriginalABC: >>>Problem: P, Epoch: 69, Current best: -101.67092150871964, Global best: -102.50204335418, Runtime: 0.07819 seconds
# 2026/03/07 11:32:57 AM, INFO, mealpy.swarm_based.ABC.OriginalABC: >>>Problem: P, Epoch: 70, Current best: -101.67092150871964, Global best: -102.50204335418, Runtime: 0.08113 seconds
# 2026/03/07 11:32:57 AM, INFO, mealpy.swarm_based.ABC.OriginalABC: >>>Problem: P, Epoch: 71, Current best: -101.67092150871964, Global best: -102.50204335418, Runtime: 0.10841 seconds
# 2026/03/07 11:32:57 AM, INFO, mealpy.swarm_based.ABC.OriginalABC: >>>Problem: P, Epoch: 72, Current best: -101.67092150871964, Global best: -102.50204335418, Runtime: 0.07856 seconds
# 2026/03/07 11:32:57 AM, INFO, mealpy.swarm_based.ABC.OriginalABC: >>>Problem: P, Epoch: 73, Current best: -101.67092150871964, Global best: -102.50204335418, Runtime: 0.07566 seconds
# 2026/03/07 11:32:57 AM, INFO, mealpy.swarm_based.ABC.OriginalABC: >>>Problem: P, Epoch: 74, Current best: -101.67092150871964, Global best: -102.50204335418, Runtime: 0.07636 seconds
# 2026/03/07 11:32:57 AM, INFO, mealpy.swarm_based.ABC.OriginalABC: >>>Problem: P, Epoch: 75, Current best: -101.67092150871964, Global best: -102.50204335418, Runtime: 0.07645 seconds
# 2026/03/07 11:32:57 AM, INFO, mealpy.swarm_based.ABC.OriginalABC: >>>Problem: P, Epoch: 76, Current best: -101.67092150871964, Global best: -102.50204335418, Runtime: 0.08085 seconds
# 2026/03/07 11:32:57 AM, INFO, mealpy.swarm_based.ABC.OriginalABC: >>>Problem: P, Epoch: 77, Current best: -101.67092150871964, Global best: -102.50204335418, Runtime: 0.07629 seconds
# 2026/03/07 11:32:57 AM, INFO, mealpy.swarm_based.ABC.OriginalABC: >>>Problem: P, Epoch: 78, Current best: -101.67092150871964, Global best: -102.50204335418, Runtime: 0.07949 seconds
# 2026/03/07 11:32:57 AM, INFO, mealpy.swarm_based.ABC.OriginalABC: >>>Problem: P, Epoch: 79, Current best: -101.60094173622737, Global best: -102.50204335418, Runtime: 0.08255 seconds
# 2026/03/07 11:32:57 AM, INFO, mealpy.swarm_based.ABC.OriginalABC: >>>Problem: P, Epoch: 80, Current best: -101.60094173622737, Global best: -102.50204335418, Runtime: 0.07561 seconds
# 2026/03/07 11:32:57 AM, INFO, mealpy.swarm_based.ABC.OriginalABC: >>>Problem: P, Epoch: 81, Current best: -101.60094173622737, Global best: -102.50204335418, Runtime: 0.07479 seconds
# 2026/03/07 11:32:58 AM, INFO, mealpy.swarm_based.ABC.OriginalABC: >>>Problem: P, Epoch: 82, Current best: -101.60094173622737, Global best: -102.50204335418, Runtime: 0.07655 seconds
# 2026/03/07 11:32:58 AM, INFO, mealpy.swarm_based.ABC.OriginalABC: >>>Problem: P, Epoch: 83, Current best: -101.60094173622737, Global best: -102.50204335418, Runtime: 0.07737 seconds
# 2026/03/07 11:32:58 AM, INFO, mealpy.swarm_based.ABC.OriginalABC: >>>Problem: P, Epoch: 84, Current best: -102.18170692829402, Global best: -102.50204335418, Runtime: 0.07911 seconds
# 2026/03/07 11:32:58 AM, INFO, mealpy.swarm_based.ABC.OriginalABC: >>>Problem: P, Epoch: 85, Current best: -102.18170692829402, Global best: -102.50204335418, Runtime: 0.07896 seconds
# 2026/03/07 11:32:58 AM, INFO, mealpy.swarm_based.ABC.OriginalABC: >>>Problem: P, Epoch: 86, Current best: -102.76834800640498, Global best: -102.76834800640498, Runtime: 0.07794 seconds
# 2026/03/07 11:32:58 AM, INFO, mealpy.swarm_based.ABC.OriginalABC: >>>Problem: P, Epoch: 87, Current best: -102.76834800640498, Global best: -102.76834800640498, Runtime: 0.07803 seconds
# 2026/03/07 11:32:58 AM, INFO, mealpy.swarm_based.ABC.OriginalABC: >>>Problem: P, Epoch: 88, Current best: -102.76834800640498, Global best: -102.76834800640498, Runtime: 0.08230 seconds
# 2026/03/07 11:32:58 AM, INFO, mealpy.swarm_based.ABC.OriginalABC: >>>Problem: P, Epoch: 89, Current best: -102.76834800640498, Global best: -102.76834800640498, Runtime: 0.07996 seconds
# 2026/03/07 11:32:58 AM, INFO, mealpy.swarm_based.ABC.OriginalABC: >>>Problem: P, Epoch: 90, Current best: -102.76834800640498, Global best: -102.76834800640498, Runtime: 0.07987 seconds
# 2026/03/07 11:32:58 AM, INFO, mealpy.swarm_based.ABC.OriginalABC: >>>Problem: P, Epoch: 91, Current best: -102.76834800640498, Global best: -102.76834800640498, Runtime: 0.07764 seconds
# 2026/03/07 11:32:58 AM, INFO, mealpy.swarm_based.ABC.OriginalABC: >>>Problem: P, Epoch: 92, Current best: -102.76834800640498, Global best: -102.76834800640498, Runtime: 0.07808 seconds
# 2026/03/07 11:32:58 AM, INFO, mealpy.swarm_based.ABC.OriginalABC: >>>Problem: P, Epoch: 93, Current best: -102.76834800640498, Global best: -102.76834800640498, Runtime: 0.07904 seconds
# 2026/03/07 11:32:59 AM, INFO, mealpy.swarm_based.ABC.OriginalABC: >>>Problem: P, Epoch: 94, Current best: -102.76834800640498, Global best: -102.76834800640498, Runtime: 0.08128 seconds
# 2026/03/07 11:32:59 AM, INFO, mealpy.swarm_based.ABC.OriginalABC: >>>Problem: P, Epoch: 95, Current best: -98.37193281061981, Global best: -102.76834800640498, Runtime: 0.07965 seconds
# 2026/03/07 11:32:59 AM, INFO, mealpy.swarm_based.ABC.OriginalABC: >>>Problem: P, Epoch: 96, Current best: -98.37193281061981, Global best: -102.76834800640498, Runtime: 0.07797 seconds
# 2026/03/07 11:32:59 AM, INFO, mealpy.swarm_based.ABC.OriginalABC: >>>Problem: P, Epoch: 97, Current best: -98.37193281061981, Global best: -102.76834800640498, Runtime: 0.07540 seconds
# 2026/03/07 11:32:59 AM, INFO, mealpy.swarm_based.ABC.OriginalABC: >>>Problem: P, Epoch: 98, Current best: -98.37193281061981, Global best: -102.76834800640498, Runtime: 0.07455 seconds
# 2026/03/07 11:32:59 AM, INFO, mealpy.swarm_based.ABC.OriginalABC: >>>Problem: P, Epoch: 99, Current best: -98.37193281061981, Global best: -102.76834800640498, Runtime: 0.08067 seconds
# 2026/03/07 11:32:59 AM, INFO, mealpy.swarm_based.ABC.OriginalABC: >>>Problem: P, Epoch: 100, Current best: -98.37193281061981, Global best: -102.76834800640498, Runtime: 0.07579 seconds
# Mejor Fitness (SSE) encontrado por ABC: -102.76834800640498

# %%
# 5. FASE HÍBRIDA: Refinamiento Local con K-Means
# Usamos los centros encontrados por las abejas como semilla
init_centroids = best_pos.reshape((n_clusters, n_features))

kmeans_final = KMeans(n_clusters=n_clusters, init=init_centroids, n_init=1, max_iter=500)
pca_data['cluster_hibrido'] = kmeans_final.fit_predict(data)

print(f"Refinamiento K-Means completado. SSE Final: {kmeans_final.inertia_}")
# Out:
# Refinamiento K-Means completado. SSE Final: 6361.156843019494

# %%
pca_labels = ['PC1', 'PC2']

fig_2, axes_2 = plt.subplots(1, 2, figsize=(12, 5))
sns.scatterplot(
    data=pca_data, 
    x=pca_labels[0], 
    y=pca_labels[1], 
    hue='cluster_hibrido', 
    palette='viridis', 
    s=70, 
    alpha=0.8,
    edgecolor='w',
    ax=axes_2[0],
)

sns.histplot(data=pca_data, x='cluster_hibrido', ax=axes_2[1])

axes_2[0].set_title("Clusters ABC-K")
axes_2[0].set_xlabel(f'{pca_labels[0]}')
axes_2[0].set_ylabel(f'{pca_labels[1]}')

axes_2[1].set_title("Distribución clusters ABC-K")
axes_2[1].set_xlabel('Clusters')
axes_2[1].set_ylabel('Frecuencia')

plt.grid(True, linestyle='--', alpha=0.50)
plt.show()

# %%
pca_data.head()
pca_data.to_csv("./results/pca_data_abck.csv", index=False, sep=',', encoding='utf-8')

# %% [markdown]
# ### Convirtiendo modelo a binario

# %%
joblib.dump(kmeans_final.cluster_centers_, './binary/cluster_centers.joblib')
# Out:
# ['./binary/cluster_centers.joblib']
