# %%
import joblib
import numpy as np
import pandas as pd

# %%
# Cargar objetos generados en etapas previas
data_scaler = joblib.load('./binary/scaler_obj.joblib')
pca_model = joblib.load('./binary/pca_obj.joblib')
cluster_centers = joblib.load('./binary/cluster_centers.joblib')
print(cluster_centers.shape)
print(cluster_centers)

# Obteniendo lista de parametros
data_columns = pd.read_csv('./results/data_fixed.csv').columns.to_list()
print(data_columns)
# Out:
# (3, 11)
# [[ 1.79530931e+00 -5.58343421e-01  3.50953692e-01 -5.94008385e-03
#   -9.85221857e-02  4.44425884e-02  5.94453487e-02 -1.14245456e-01
#    3.07982575e-02 -3.38125726e-02  1.00000000e+00]
#  [-1.05924189e+00  2.39964091e-01 -2.47758147e-01 -1.37747622e-02
#    5.65612910e-02 -3.27452893e-02 -3.03617978e-02  6.11485237e-02
#   -1.36740508e-02  9.42849685e-03 -3.33066907e-16]
#  [ 6.77022384e+00  1.60551264e+01  9.58427556e+00  3.48532644e+00
#   -5.33685340e-02  1.49195348e+00 -7.32215500e-01  8.39322625e-01
#   -7.96765567e-01  2.00827356e+00  2.00000000e+00]]
# ['cadmio', 'cobre', 'coliformes_termotolerantes', 'coliformes_totales', 'cromo', 'dbo5', 'dqo', 'hierro', 'manganeso', 'niquel', 'ph', 'plomo', 'solidos_suspendidos', 'solidos_totales', 'zinc', 'fecha', 'referencia']

# %%
# Revirtiendo centroides a las 16 dimensiones del perfil quimico

centroides_pca = cluster_centers.reshape((3, 10))
cluster_centers_15d = pca_model.inverse_transform(centroides_pca)
print(cluster_centers_15d)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 3
#       1 # Revirtiendo centroides a las 16 dimensiones del perfil quimico
# ----> 3 centroides_pca = cluster_centers.reshape((3, 10))
#       4 cluster_centers_15d = pca_model.inverse_transform(centroides_pca)
#       5 print(cluster_centers_15d)
#
# ValueError: cannot reshape array of size 33 into shape (3,10)

# %%
# Guardando objetos escenciales para uso de modelo
n_clusters = 3
n_features = 10

modelo_completo = {
    'scaler': data_scaler,
    'pca': pca_model,
    'cluster_centers_pca': cluster_centers.reshape((n_clusters, n_features)),
    'cluster_centers_15d': cluster_centers_15d,
    'columnas_originales': data_columns,
    'metadata': {
        'n_clusters': n_clusters,
        'n_features_pca': n_features, 
        'n_features_abck': 5,
        'description': 'Modelo ABC-K Perfiles Químicos Relleno Sanitario',
        'version': '0.0.1',
        'date': '2026-07-03',
        'dev': ['perez_jose', 'mikdevio'],
    }
}

# %%
# Guardado de binario
joblib.dump(modelo_completo, './binary/model_clasificador_lix.joblib')
# Out:
# ['./binary/model_clasificador_lix.joblib']
